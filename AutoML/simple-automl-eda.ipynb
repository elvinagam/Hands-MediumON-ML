# %%
import pandas as pd

# %%
# from kaggle.competitions import nflrush
# # env = nflrush.make_env()
# from kaggle.

# %%
train = pd.read_csv("../input/nfl-big-data-bowl-2020/train.csv", low_memory=False)

# %% [markdown]
# Data Visualization, General Information and Dataframe Description

# %%
import pandas_profiling

# %%
viz = pandas_profiling.ProfileReport(train)

# %%
viz.to_widgets()

# %% [markdown]
# Missing Data

# %%
import missingno as msno
msno.matrix(train)

# %%
msno.bar(train)

# %% [markdown]
# Which Columns have Nan values?

# %%
for col in range(len(train.columns)):
    n = train.iloc[:, col].isnull().sum()
    if n > 0:
        print(list(train.columns.values)[col] + ": "+ str(n) + " Nan")
# Out:
# Orientation: 23 Nan
# Dir: 28 Nan
# FieldPosition: 8602 Nan
# OffenseFormation: 88 Nan
# DefendersInTheBox: 22 Nan
# StadiumType: 41690 Nan
# GameWeather: 60170 Nan
# Temperature: 63646 Nan
# Humidity: 6160 Nan
# WindSpeed: 91872 Nan
# WindDirection: 104676 Nan

# %%
pd.set_option('max_columns', 100)
train
# Out:
#             GameId          PlayId  Team      X      Y     S     A   Dis  \
# 0       2017090700  20170907000118  away  73.91  34.84  1.69  1.13  0.40
# 1       2017090700  20170907000118  away  74.67  32.64  0.42  1.35  0.01
# 2       2017090700  20170907000118  away  74.00  33.20  1.22  0.59  0.31
# 3       2017090700  20170907000118  away  71.46  27.70  0.42  0.54  0.02
# 4       2017090700  20170907000118  away  69.32  35.42  1.82  2.43  0.16
# ...            ...             ...   ...    ...    ...   ...   ...   ...
# 682149  2019112500  20191125003789  home  69.58  31.33  4.19  1.33  0.43
# 682150  2019112500  20191125003789  home  72.16  25.09  1.01  1.40  0.08
# 682151  2019112500  20191125003789  home  72.23  31.95  1.75  0.68  0.17
# 682152  2019112500  20191125003789  home  72.08  26.74  0.70  1.59  0.07
# 682153  2019112500  20191125003789  home  68.11  24.67  4.71  1.30  0.47
#
#         Orientation     Dir    NflId      DisplayName  JerseyNumber  Season  \
# ...

# %%
train
# Out:
#             GameId          PlayId  Team      X      Y     S     A   Dis  \
# 0       2017090700  20170907000118  away  73.91  34.84  1.69  1.13  0.40
# 1       2017090700  20170907000118  away  74.67  32.64  0.42  1.35  0.01
# 2       2017090700  20170907000118  away  74.00  33.20  1.22  0.59  0.31
# 3       2017090700  20170907000118  away  71.46  27.70  0.42  0.54  0.02
# 4       2017090700  20170907000118  away  69.32  35.42  1.82  2.43  0.16
# ...            ...             ...   ...    ...    ...   ...   ...   ...
# 682149  2019112500  20191125003789  home  69.58  31.33  4.19  1.33  0.43
# 682150  2019112500  20191125003789  home  72.16  25.09  1.01  1.40  0.08
# 682151  2019112500  20191125003789  home  72.23  31.95  1.75  0.68  0.17
# 682152  2019112500  20191125003789  home  72.08  26.74  0.70  1.59  0.07
# 682153  2019112500  20191125003789  home  68.11  24.67  4.71  1.30  0.47
#
#         Orientation     Dir    NflId      DisplayName  JerseyNumber  Season  \
# ...
